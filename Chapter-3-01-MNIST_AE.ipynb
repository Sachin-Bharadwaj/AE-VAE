# %% [markdown]
# # Autoencoder

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from utils.loaders import load_mnist
from models.AE import Autoencoder
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Set parameters

# %%
import pathlib

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = './run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

p = pathlib.Path(RUN_FOLDER)

if not p.exists():
    p.mkdir(parents=True, exist_ok=False)
    (p/'viz').mkdir(parents=True, exist_ok=False)
    (p/'images').mkdir(parents=True, exist_ok=False)
    (p/'weights').mkdir(parents=True, exist_ok=False)
    
MODE =  'build' #'load' #

# %% [markdown]
# # Load MNIST data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# # Architecture of the AutoEncoder

# %%
AE = Autoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if MODE == 'build':
    AE.save(RUN_FOLDER)
else:
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
AE.encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 28, 28, 1)         0
# _________________________________________________________________
# encoder_conv_0 (Conv2D)      (None, 28, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# encoder_conv_1 (Conv2D)      (None, 14, 14, 64)        18496
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# encoder_conv_2 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# encoder_conv_3 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 6274
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #  Train the AE

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH = 0

# %%
AE.compile(LEARNING_RATE)

# %%
AE.train(     
    x_train[:1000]
    , batch_size = BATCH_SIZE
    , epochs = 400
    , run_folder = RUN_FOLDER
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/400
#  384/1000 [==========>...................] - ETA: 14s - loss: 0.2274
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.195614). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.1890
#
# Epoch 00001: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 2/400
# 1000/1000 [==============================] - 1s 525us/step - loss: 0.0866
#
# Epoch 00002: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 3/400
#  288/1000 [=======>......................] - ETA: 2s - loss: 0.0688
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (1.015806). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.507903). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0670
#
# Epoch 00003: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 4/400
# 1000/1000 [==============================] - 0s 477us/step - loss: 0.0618
#
# Epoch 00004: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 5/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0572
#
# Epoch 00005: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 6/400
# 1000/1000 [==============================] - 0s 444us/step - loss: 0.0559
#
# Epoch 00006: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 7/400
#  384/1000 [==========>...................] - ETA: 0s - loss: 0.0537
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.331264). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.165632). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 823us/step - loss: 0.0549
#
# Epoch 00007: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 8/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0541
#
# Epoch 00008: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 9/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0535 0s - loss: 0.053
#
# Epoch 00009: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 10/400
# 1000/1000 [==============================] - 0s 477us/step - loss: 0.0530
#
# Epoch 00010: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 11/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0525
#
# Epoch 00011: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 12/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0520
#
# Epoch 00012: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 13/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0517
#
# Epoch 00013: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 14/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0513
#
# Epoch 00014: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 15/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0509
#
# Epoch 00015: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 16/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0506
#
# Epoch 00016: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 17/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0502
#
# Epoch 00017: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 18/400
#  288/1000 [=======>......................] - ETA: 2s - loss: 0.0493
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.732605). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.366302). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0499
#
# Epoch 00018: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 19/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0498
#
# Epoch 00019: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 20/400
# 1000/1000 [==============================] - 0s 475us/step - loss: 0.0493
#
# Epoch 00020: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 21/400
# 1000/1000 [==============================] - 0s 460us/step - loss: 0.0490
#
# Epoch 00021: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 22/400
# 1000/1000 [==============================] - 0s 470us/step - loss: 0.0488
#
# Epoch 00022: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 23/400
# 1000/1000 [==============================] - 0s 473us/step - loss: 0.0487
#
# Epoch 00023: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 24/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0483
#
# Epoch 00024: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 25/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0481
#
# Epoch 00025: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 26/400
# 1000/1000 [==============================] - 1s 519us/step - loss: 0.0477
#
# Epoch 00026: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 27/400
# 1000/1000 [==============================] - 1s 507us/step - loss: 0.0475
#
# Epoch 00027: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 28/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0473
#
# Epoch 00028: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 29/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0471
#
# Epoch 00029: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 30/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0470
#
# Epoch 00030: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 31/400
#  288/1000 [=======>......................] - ETA: 0s - loss: 0.0477
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.230520). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.115260). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 722us/step - loss: 0.0468
#
# Epoch 00031: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 32/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0465
#
# Epoch 00032: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 33/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0464
#
# Epoch 00033: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 34/400
# 1000/1000 [==============================] - 1s 595us/step - loss: 0.0462
#
# Epoch 00034: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 35/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0459
#
# Epoch 00035: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 36/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0459
#
# Epoch 00036: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 37/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0458
#
# Epoch 00037: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 38/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0454
#
# Epoch 00038: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 39/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0453
#
# Epoch 00039: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 40/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0451
#
# Epoch 00040: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 41/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0449
#
# Epoch 00041: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 42/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0448
#
# Epoch 00042: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 43/400
# 1000/1000 [==============================] - 0s 461us/step - loss: 0.0449
#
# Epoch 00043: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 44/400
# 1000/1000 [==============================] - 0s 473us/step - loss: 0.0448
#
# Epoch 00044: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 45/400
# 1000/1000 [==============================] - 0s 458us/step - loss: 0.0445
#
# Epoch 00045: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 46/400
# 1000/1000 [==============================] - 0s 464us/step - loss: 0.0443
#
# Epoch 00046: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 47/400
#  448/1000 [============>.................] - ETA: 0s - loss: 0.0450
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.467942). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.233971). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0442
#
# Epoch 00047: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 48/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0437
#
# Epoch 00048: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 49/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0437
#
# Epoch 00049: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 50/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0436
#
# Epoch 00050: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 51/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0435
#
# Epoch 00051: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 52/400
# 1000/1000 [==============================] - 0s 475us/step - loss: 0.0436
#
# Epoch 00052: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 53/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0435
#
# Epoch 00053: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 54/400
# 1000/1000 [==============================] - 0s 468us/step - loss: 0.0431
#
# Epoch 00054: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 55/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0429
#
# Epoch 00055: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 56/400
# 1000/1000 [==============================] - 0s 500us/step - loss: 0.0435
#
# Epoch 00056: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 57/400
# 1000/1000 [==============================] - 0s 479us/step - loss: 0.0428
#
# Epoch 00057: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 58/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0426
#
# Epoch 00058: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 59/400
#  256/1000 [======>.......................] - ETA: 1s - loss: 0.0447
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.482253). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.241127). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 977us/step - loss: 0.0423
#
# Epoch 00059: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 60/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0422
#
# Epoch 00060: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 61/400
# 1000/1000 [==============================] - 0s 468us/step - loss: 0.0421
#
# Epoch 00061: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 62/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0419
#
# Epoch 00062: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 63/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0418
#
# Epoch 00063: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 64/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0417
#
# Epoch 00064: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 65/400
# 1000/1000 [==============================] - 0s 468us/step - loss: 0.0417
#
# Epoch 00065: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 66/400
# 1000/1000 [==============================] - 0s 477us/step - loss: 0.0415
#
# Epoch 00066: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 67/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0414
#
# Epoch 00067: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 68/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0412
#
# Epoch 00068: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 69/400
# 1000/1000 [==============================] - 0s 470us/step - loss: 0.0412
#
# Epoch 00069: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 70/400
# 1000/1000 [==============================] - 0s 464us/step - loss: 0.0411
#
# Epoch 00070: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 71/400
# 1000/1000 [==============================] - 0s 470us/step - loss: 0.0410
#
# Epoch 00071: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 72/400
# 1000/1000 [==============================] - 0s 479us/step - loss: 0.0409
#
# Epoch 00072: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 73/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0408
#
# Epoch 00073: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 74/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0405
#
# Epoch 00074: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 75/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0406
#
# Epoch 00075: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 76/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0406
#
# Epoch 00076: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 77/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0404
#
# Epoch 00077: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 78/400
# 1000/1000 [==============================] - 1s 534us/step - loss: 0.0402
#
# Epoch 00078: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 79/400
# 1000/1000 [==============================] - 1s 535us/step - loss: 0.0403
#
# Epoch 00079: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 80/400
# 1000/1000 [==============================] - 1s 517us/step - loss: 0.0401
#
# Epoch 00080: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 81/400
# 1000/1000 [==============================] - 0s 462us/step - loss: 0.0402
#
# Epoch 00081: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 82/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0402
#
# Epoch 00082: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 83/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0396
#
# Epoch 00083: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 84/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0396
#
# Epoch 00084: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 85/400
# 1000/1000 [==============================] - 0s 474us/step - loss: 0.0394
#
# Epoch 00085: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 86/400
# 1000/1000 [==============================] - 1s 506us/step - loss: 0.0392
#
# Epoch 00086: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 87/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0393
#
# Epoch 00087: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 88/400
# 1000/1000 [==============================] - 1s 531us/step - loss: 0.0392
#
# Epoch 00088: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 89/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0393
#
# Epoch 00089: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 90/400
# 1000/1000 [==============================] - 1s 579us/step - loss: 0.0391
#
# Epoch 00090: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 91/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0392
#
# Epoch 00091: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 92/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0389
#
# Epoch 00092: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 93/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0386
#
# Epoch 00093: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 94/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0389
#
# Epoch 00094: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 95/400
# 1000/1000 [==============================] - 0s 475us/step - loss: 0.0386
#
# Epoch 00095: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 96/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0390
#
# Epoch 00096: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 97/400
# 1000/1000 [==============================] - 1s 562us/step - loss: 0.0391
#
# Epoch 00097: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 98/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0395
#
# Epoch 00098: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 99/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0387
#
# Epoch 00099: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 100/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0385
#
# Epoch 00100: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 101/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0386
#
# Epoch 00101: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 102/400
# 1000/1000 [==============================] - 1s 558us/step - loss: 0.0383
#
# Epoch 00102: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 103/400
# 1000/1000 [==============================] - 1s 560us/step - loss: 0.0381
#
# Epoch 00103: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 104/400
# 1000/1000 [==============================] - 0s 456us/step - loss: 0.0385
#
# Epoch 00104: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 105/400
# 1000/1000 [==============================] - 0s 474us/step - loss: 0.0383
#
# Epoch 00105: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 106/400
# 1000/1000 [==============================] - 1s 512us/step - loss: 0.0383
#
# Epoch 00106: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 107/400
# 1000/1000 [==============================] - 1s 507us/step - loss: 0.0381
#
# Epoch 00107: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 108/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0379
#
# Epoch 00108: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 109/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0380
#
# Epoch 00109: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 110/400
# 1000/1000 [==============================] - 1s 523us/step - loss: 0.0378
#
# Epoch 00110: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 111/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0379
#
# Epoch 00111: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 112/400
# 1000/1000 [==============================] - 0s 466us/step - loss: 0.0379
#
# Epoch 00112: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 113/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0380
#
# Epoch 00113: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 114/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0379
#
# Epoch 00114: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 115/400
# 1000/1000 [==============================] - 1s 510us/step - loss: 0.0377
#
# Epoch 00115: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 116/400
# 1000/1000 [==============================] - 0s 465us/step - loss: 0.0378
#
# Epoch 00116: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 117/400
# 1000/1000 [==============================] - 0s 479us/step - loss: 0.0372
#
# Epoch 00117: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 118/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0377
#
# Epoch 00118: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 119/400
#  288/1000 [=======>......................] - ETA: 2s - loss: 0.0365
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.860477). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.431234). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0378
#
# Epoch 00119: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 120/400
# 1000/1000 [==============================] - 1s 506us/step - loss: 0.0378
#
# Epoch 00120: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 121/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0375
#
# Epoch 00121: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 122/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0372
#
# Epoch 00122: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 123/400
# 1000/1000 [==============================] - 1s 532us/step - loss: 0.0372
#
# Epoch 00123: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 124/400
# 1000/1000 [==============================] - 0s 456us/step - loss: 0.0374
#
# Epoch 00124: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 125/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0371
#
# Epoch 00125: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 126/400
# 1000/1000 [==============================] - 0s 476us/step - loss: 0.0371
#
# Epoch 00126: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 127/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0371
#
# Epoch 00127: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 128/400
# 1000/1000 [==============================] - 1s 518us/step - loss: 0.0369
#
# Epoch 00128: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 129/400
# 1000/1000 [==============================] - 1s 519us/step - loss: 0.0370 0s - loss: 0.03
#
# Epoch 00129: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 130/400
# 1000/1000 [==============================] - 1s 558us/step - loss: 0.0368
#
# Epoch 00130: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 131/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0368
#
# Epoch 00131: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 132/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0368
#
# Epoch 00132: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 133/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0371
#
# Epoch 00133: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 134/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0372
#
# Epoch 00134: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 135/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0372
#
# Epoch 00135: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 136/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0370
#
# Epoch 00136: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 137/400
# 1000/1000 [==============================] - 0s 473us/step - loss: 0.0369
#
# Epoch 00137: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 138/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0365
#
# Epoch 00138: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 139/400
#  416/1000 [===========>..................] - ETA: 1s - loss: 0.0364
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (1.055403). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.527701). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0367
#
# Epoch 00139: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 140/400
# 1000/1000 [==============================] - 0s 474us/step - loss: 0.0365
#
# Epoch 00140: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 141/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0365
#
# Epoch 00141: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 142/400
# 1000/1000 [==============================] - 1s 548us/step - loss: 0.0367
#
# Epoch 00142: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 143/400
# 1000/1000 [==============================] - 0s 463us/step - loss: 0.0364
#
# Epoch 00143: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 144/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0368
#
# Epoch 00144: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 145/400
# 1000/1000 [==============================] - 0s 468us/step - loss: 0.0364
#
# Epoch 00145: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 146/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0368
#
# Epoch 00146: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 147/400
# 1000/1000 [==============================] - 0s 477us/step - loss: 0.0367
#
# Epoch 00147: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 148/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0367
#
# Epoch 00148: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 149/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0364
#
# Epoch 00149: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 150/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0363
#
# Epoch 00150: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 151/400
# 1000/1000 [==============================] - 0s 476us/step - loss: 0.0364
#
# Epoch 00151: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 152/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0364
#
# Epoch 00152: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 153/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0365
#
# Epoch 00153: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 154/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0360
#
# Epoch 00154: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 155/400
# 1000/1000 [==============================] - 0s 470us/step - loss: 0.0359
#
# Epoch 00155: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 156/400
# 1000/1000 [==============================] - 0s 500us/step - loss: 0.0360
#
# Epoch 00156: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 157/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0360
#
# Epoch 00157: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 158/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0360
#
# Epoch 00158: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 159/400
#  288/1000 [=======>......................] - ETA: 1s - loss: 0.0378
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.461346). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.230673). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0360
#
# Epoch 00159: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 160/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0363
#
# Epoch 00160: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 161/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0357
#
# Epoch 00161: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 162/400
# 1000/1000 [==============================] - 1s 536us/step - loss: 0.0359
#
# Epoch 00162: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 163/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0362
#
# Epoch 00163: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 164/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0357
#
# Epoch 00164: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 165/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0359
#
# Epoch 00165: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 166/400
# 1000/1000 [==============================] - 0s 453us/step - loss: 0.0359
#
# Epoch 00166: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 167/400
# 1000/1000 [==============================] - 0s 465us/step - loss: 0.0357
#
# Epoch 00167: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 168/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0358
#
# Epoch 00168: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 169/400
# 1000/1000 [==============================] - 0s 461us/step - loss: 0.0359
#
# Epoch 00169: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 170/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0355
#
# Epoch 00170: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 171/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0355
#
# Epoch 00171: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 172/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0355
#
# Epoch 00172: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 173/400
# 1000/1000 [==============================] - 0s 471us/step - loss: 0.0356
#
# Epoch 00173: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 174/400
# 1000/1000 [==============================] - 1s 560us/step - loss: 0.0356
#
# Epoch 00174: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 175/400
# 1000/1000 [==============================] - 1s 540us/step - loss: 0.0354
#
# Epoch 00175: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 176/400
# 1000/1000 [==============================] - ETA: 0s - loss: 0.035 - 1s 502us/step - loss: 0.0355
#
# Epoch 00176: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 177/400
# 1000/1000 [==============================] - 1s 517us/step - loss: 0.0358
#
# Epoch 00177: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 178/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0354
#
# Epoch 00178: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 179/400
#  256/1000 [======>.......................] - ETA: 1s - loss: 0.0347
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.420937). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.210977). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 946us/step - loss: 0.0356
#
# Epoch 00179: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 180/400
# 1000/1000 [==============================] - 0s 461us/step - loss: 0.0356
#
# Epoch 00180: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 181/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0357
#
# Epoch 00181: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 182/400
# 1000/1000 [==============================] - 0s 465us/step - loss: 0.0357
#
# Epoch 00182: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 183/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0361
#
# Epoch 00183: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 184/400
# 1000/1000 [==============================] - 0s 463us/step - loss: 0.0358
#
# Epoch 00184: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 185/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0353
#
# Epoch 00185: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 186/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0354
#
# Epoch 00186: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 187/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0354
#
# Epoch 00187: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 188/400
# 1000/1000 [==============================] - 1s 507us/step - loss: 0.0355
#
# Epoch 00188: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 189/400
# 1000/1000 [==============================] - 1s 559us/step - loss: 0.0354
#
# Epoch 00189: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 190/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0353
#
# Epoch 00190: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 191/400
#  448/1000 [============>.................] - ETA: 0s - loss: 0.0349
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.580129). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.290065). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0351
#
# Epoch 00191: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 192/400
# 1000/1000 [==============================] - 0s 473us/step - loss: 0.0349
#
# Epoch 00192: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 193/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0349
#
# Epoch 00193: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 194/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0350
#
# Epoch 00194: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 195/400
# 1000/1000 [==============================] - 1s 585us/step - loss: 0.0352
#
# Epoch 00195: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 196/400
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.0353
#
# Epoch 00196: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 197/400
# 1000/1000 [==============================] - 1s 647us/step - loss: 0.0354
#
# Epoch 00197: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 198/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0354
#
# Epoch 00198: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 199/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0349
#
# Epoch 00199: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 200/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0348
#
# Epoch 00200: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 201/400
# 1000/1000 [==============================] - 1s 510us/step - loss: 0.0346
#
# Epoch 00201: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 202/400
# 1000/1000 [==============================] - 1s 506us/step - loss: 0.0349
#
# Epoch 00202: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 203/400
#  256/1000 [======>.......................] - ETA: 0s - loss: 0.0343
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.172772). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.0348
#
# Epoch 00203: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 204/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0348
#
# Epoch 00204: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 205/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0346
#
# Epoch 00205: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 206/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0347
#
# Epoch 00206: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 207/400
#  288/1000 [=======>......................] - ETA: 1s - loss: 0.0348
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.649334). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.324667). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0349
#
# Epoch 00207: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 208/400
# 1000/1000 [==============================] - 1s 508us/step - loss: 0.0347
#
# Epoch 00208: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 209/400
# 1000/1000 [==============================] - 1s 510us/step - loss: 0.0345
#
# Epoch 00209: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 210/400
# 1000/1000 [==============================] - 1s 513us/step - loss: 0.0352
#
# Epoch 00210: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 211/400
# 1000/1000 [==============================] - 0s 498us/step - loss: 0.0347
#
# Epoch 00211: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 212/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0352
#
# Epoch 00212: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 213/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0353
#
# Epoch 00213: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 214/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0349
#
# Epoch 00214: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 215/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0348
#
# Epoch 00215: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 216/400
#  256/1000 [======>.......................] - ETA: 2s - loss: 0.0338
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.843587). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.421794). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0345
#
# Epoch 00216: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 217/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0348
#
# Epoch 00217: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 218/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0344
#
# Epoch 00218: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 219/400
# 1000/1000 [==============================] - 1s 597us/step - loss: 0.0346
#
# Epoch 00219: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 220/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0347
#
# Epoch 00220: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 221/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0351
#
# Epoch 00221: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 222/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0345
#
# Epoch 00222: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 223/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0345
#
# Epoch 00223: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 224/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0342
#
# Epoch 00224: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 225/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0346
#
# Epoch 00225: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 226/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0346
#
# Epoch 00226: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 227/400
#  288/1000 [=======>......................] - ETA: 0s - loss: 0.0340
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.156592). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 656us/step - loss: 0.0345
#
# Epoch 00227: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 228/400
# 1000/1000 [==============================] - 0s 472us/step - loss: 0.0346
#
# Epoch 00228: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 229/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0345
#
# Epoch 00229: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 230/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0349
#
# Epoch 00230: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 231/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0344
#
# Epoch 00231: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 232/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0342
#
# Epoch 00232: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 233/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0342
#
# Epoch 00233: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 234/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0341
#
# Epoch 00234: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 235/400
#  384/1000 [==========>...................] - ETA: 1s - loss: 0.0353
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.648205). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.324103). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0341
#
# Epoch 00235: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 236/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0342
#
# Epoch 00236: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 237/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0342
#
# Epoch 00237: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 238/400
# 1000/1000 [==============================] - 0s 494us/step - loss: 0.0346
#
# Epoch 00238: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 239/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0342
#
# Epoch 00239: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 240/400
# 1000/1000 [==============================] - 0s 494us/step - loss: 0.0347
#
# Epoch 00240: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 241/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0344
#
# Epoch 00241: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 242/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0342
#
# Epoch 00242: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 243/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0342
#
# Epoch 00243: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 244/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0340
#
# Epoch 00244: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 245/400
# 1000/1000 [==============================] - 0s 468us/step - loss: 0.0339
#
# Epoch 00245: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 246/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0338
#
# Epoch 00246: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 247/400
# ...
# Epoch 304/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0331
#
# Epoch 00304: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 305/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0334
#
# Epoch 00305: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 306/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0334
#
# Epoch 00306: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 307/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0334
#
# Epoch 00307: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 308/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0332
#
# Epoch 00308: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 309/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0330
#
# Epoch 00309: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 310/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0328
#
# Epoch 00310: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 311/400
# 1000/1000 [==============================] - 0s 463us/step - loss: 0.0328
#
# Epoch 00311: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 312/400
# 1000/1000 [==============================] - 0s 500us/step - loss: 0.0330
#
# Epoch 00312: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 313/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0330
#
# Epoch 00313: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 314/400
# 1000/1000 [==============================] - 0s 498us/step - loss: 0.0328
#
# Epoch 00314: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 315/400
# 1000/1000 [==============================] - 0s 465us/step - loss: 0.0329
#
# Epoch 00315: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 316/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0325
#
# Epoch 00316: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 317/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0327
#
# Epoch 00317: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 318/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0326
#
# Epoch 00318: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 319/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0328
#
# Epoch 00319: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 320/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0327
#
# Epoch 00320: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 321/400
# 1000/1000 [==============================] - 0s 483us/step - loss: 0.0329
#
# Epoch 00321: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 322/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0329
#
# Epoch 00322: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 323/400
# 1000/1000 [==============================] - 0s 473us/step - loss: 0.0328
#
# Epoch 00323: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 324/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0328
#
# Epoch 00324: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 325/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0325
#
# Epoch 00325: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 326/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0326
#
# Epoch 00326: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 327/400
# 1000/1000 [==============================] - 1s 551us/step - loss: 0.0325
#
# Epoch 00327: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 328/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0329
#
# Epoch 00328: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 329/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0332
#
# Epoch 00329: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 330/400
# 1000/1000 [==============================] - 1s 503us/step - loss: 0.0329
#
# Epoch 00330: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 331/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0328
#
# Epoch 00331: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 332/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0326
#
# Epoch 00332: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 333/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0328
#
# Epoch 00333: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 334/400
# 1000/1000 [==============================] - 1s 509us/step - loss: 0.0332
#
# Epoch 00334: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 335/400
# 1000/1000 [==============================] - 1s 517us/step - loss: 0.0330
#
# Epoch 00335: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 336/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0327
#
# Epoch 00336: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 337/400
# 1000/1000 [==============================] - 0s 492us/step - loss: 0.0327
#
# Epoch 00337: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 338/400
# 1000/1000 [==============================] - 0s 469us/step - loss: 0.0324
#
# Epoch 00338: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 339/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0326
#
# Epoch 00339: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 340/400
# 1000/1000 [==============================] - 0s 480us/step - loss: 0.0332
#
# Epoch 00340: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 341/400
# 1000/1000 [==============================] - 0s 497us/step - loss: 0.0329
#
# Epoch 00341: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 342/400
# 1000/1000 [==============================] - 1s 506us/step - loss: 0.0331
#
# Epoch 00342: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 343/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0330
#
# Epoch 00343: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 344/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0326
#
# Epoch 00344: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 345/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0325
#
# Epoch 00345: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 346/400
# 1000/1000 [==============================] - 1s 501us/step - loss: 0.0326
#
# Epoch 00346: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 347/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0323
#
# Epoch 00347: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 348/400
# 1000/1000 [==============================] - 0s 481us/step - loss: 0.0322
#
# Epoch 00348: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 349/400
# 1000/1000 [==============================] - 1s 504us/step - loss: 0.0323
#
# Epoch 00349: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 350/400
# 1000/1000 [==============================] - 0s 478us/step - loss: 0.0323
#
# Epoch 00350: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 351/400
#  288/1000 [=======>......................] - ETA: 1s - loss: 0.0307
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.575808). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# C:\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.287904). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0324
#
# Epoch 00351: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 352/400
# 1000/1000 [==============================] - 0s 475us/step - loss: 0.0326
#
# Epoch 00352: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 353/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0326
#
# Epoch 00353: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 354/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0322
#
# Epoch 00354: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 355/400
# 1000/1000 [==============================] - 0s 494us/step - loss: 0.0322
#
# Epoch 00355: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 356/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0325
#
# Epoch 00356: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 357/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0326
#
# Epoch 00357: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 358/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0325
#
# Epoch 00358: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 359/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0321
#
# Epoch 00359: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 360/400
# 1000/1000 [==============================] - 0s 479us/step - loss: 0.0324
#
# Epoch 00360: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 361/400
# 1000/1000 [==============================] - 0s 494us/step - loss: 0.0325
#
# Epoch 00361: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 362/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0324
#
# Epoch 00362: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 363/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0323
#
# Epoch 00363: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 364/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0322
#
# Epoch 00364: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 365/400
# 1000/1000 [==============================] - 0s 500us/step - loss: 0.0323
#
# Epoch 00365: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 366/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0323
#
# Epoch 00366: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 367/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0329
#
# Epoch 00367: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 368/400
# 1000/1000 [==============================] - 0s 475us/step - loss: 0.0323
#
# Epoch 00368: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 369/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0321
#
# Epoch 00369: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 370/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0321
#
# Epoch 00370: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 371/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0323
#
# Epoch 00371: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 372/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0320
#
# Epoch 00372: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 373/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0326
#
# Epoch 00373: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 374/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0319
#
# Epoch 00374: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 375/400
# 1000/1000 [==============================] - 0s 499us/step - loss: 0.0320
#
# Epoch 00375: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 376/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0327
#
# Epoch 00376: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 377/400
# 1000/1000 [==============================] - 0s 496us/step - loss: 0.0324
#
# Epoch 00377: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 378/400
# 1000/1000 [==============================] - 0s 495us/step - loss: 0.0322
#
# Epoch 00378: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 379/400
# 1000/1000 [==============================] - 1s 519us/step - loss: 0.0322
#
# Epoch 00379: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 380/400
# 1000/1000 [==============================] - 0s 486us/step - loss: 0.0320
#
# Epoch 00380: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 381/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0323
#
# Epoch 00381: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 382/400
# 1000/1000 [==============================] - 0s 490us/step - loss: 0.0324
#
# Epoch 00382: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 383/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0324
#
# Epoch 00383: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 384/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0322
#
# Epoch 00384: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 385/400
# 1000/1000 [==============================] - 0s 493us/step - loss: 0.0319
#
# Epoch 00385: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 386/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0319
#
# Epoch 00386: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 387/400
# 1000/1000 [==============================] - 0s 482us/step - loss: 0.0318 0s - loss
#
# Epoch 00387: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 388/400
# 1000/1000 [==============================] - 0s 488us/step - loss: 0.0319
#
# Epoch 00388: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 389/400
# 1000/1000 [==============================] - 0s 476us/step - loss: 0.0321
#
# Epoch 00389: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 390/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0320
#
# Epoch 00390: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 391/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0324
#
# Epoch 00391: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 392/400
# 1000/1000 [==============================] - 0s 491us/step - loss: 0.0322
#
# Epoch 00392: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 393/400
# 1000/1000 [==============================] - 1s 502us/step - loss: 0.0320
#
# Epoch 00393: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 394/400
# 1000/1000 [==============================] - 0s 484us/step - loss: 0.0320
#
# Epoch 00394: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 395/400
# 1000/1000 [==============================] - 0s 487us/step - loss: 0.0320
#
# Epoch 00395: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 396/400
# 1000/1000 [==============================] - 0s 485us/step - loss: 0.0320
#
# Epoch 00396: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 397/400
# 1000/1000 [==============================] - 0s 489us/step - loss: 0.0316
#
# Epoch 00397: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 398/400
# 1000/1000 [==============================] - 0s 479us/step - loss: 0.0317
#
# Epoch 00398: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 399/400
# 1000/1000 [==============================] - 0s 498us/step - loss: 0.0318
#
# Epoch 00399: saving model to ./run/vae/0001_digits\weights/weights.h5
# Epoch 400/400
# 1000/1000 [==============================] - 0s 476us/step - loss: 0.0321
#
# Epoch 00400: saving model to ./run/vae/0001_digits\weights/weights.h5

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
import numpy as np

# %%
z = np.random.randn(2)[None,:];z
# Out:
# array([[-0.30518514, -0.91219155]])

# %%
y = AE.decoder.predict(z)

# %%
y.shape
# Out:
# (1, 28, 28, 1)

# %%
x = x_train[2000]; x[None,:].shape
# Out:
# (1, 28, 28, 1)

# %%
zz = AE.encoder.predict(x[None,:]); zz
# Out:
# array([[-2.0912402,  0.9951177]], dtype=float32)
